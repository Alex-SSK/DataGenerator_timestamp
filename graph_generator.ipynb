# %%
import pandas as pd
import os
import numpy as np

# %%
file_name = "reformed_data.csv"

# read data
data = pd.read_csv(file_name)

# %%
data = data.drop('Unnamed: 0', axis=1)

# %%
data
# Out:
#        track_id    speed  lon_acc  lat_acc   time        type  moving  img_x  \
# 0            45  38.2121   0.0151  -0.0200    0.0         Car    True   2143
# 1            45  38.0674  -0.2361  -0.0508    0.4         Car    True   2172
# 2            45  37.9157  -0.2012  -0.0602    0.8         Car    True   2202
# 3            45  37.5489  -0.3050  -0.0863    1.2         Car    True   2231
# 4            45  37.0419  -0.4114  -0.1069    1.6         Car    True   2259
# ...         ...      ...      ...      ...    ...         ...     ...    ...
# 68436      2243  50.2733  -1.5150  -0.4383  862.4  Motorcycle    True    281
# 68437      2243  48.0276  -1.4087  -1.0684  862.8  Motorcycle    True    322
# 68438      2243  46.9236   0.1524  -1.6292  863.2  Motorcycle    True    360
# 68439      2243  49.5167   3.8135  -1.8114  863.6  Motorcycle    True    399
# 68440      2243  52.4950   4.9160  -1.6269  864.0  Motorcycle    True    441
#
#        img_y  img_angle  coord_id     lc
# ...

# %%
id = data['track_id'].unique()

# %%
for i in id:
# Out:
# array([  45,   46,   50,   71,   74,  116,  165,  171,  207,  214,  217,
#         218,  220,  221,  225,  228,  232,  238,  242,  243,  246,  251,
#         255,  258,  262,  270,  279,  281,  283,  284,  288,  289,  295,
#         298,  299,  310,  311,  317,  318,  321,  330,  337,  344,  345,
#         354,  357,  359,  360,  369,  376,  380,  381,  387,  398,  408,
#         424,  430,  443,  444,  445,  449,  450,  451,  452,  455,  458,
#         460,  467,  475,  476,  501,  509,  510,  512,  513,  518,  520,
#         523,  528,  534,  535,  538,  541,  543,  546,  548,  552,  553,
#         573,  583,  587,  588,  589,  593,  596,  607,  609,  616,  621,
#         630,  646,  656,  657,  661,  664,  668,  669,  671,  673,  678,
#         683,  685,  689,  690,  699,  705,  709,  710,  711,  714,  720,
#         725,  734,  737,  745,  747,  750,  754,  760,  762,  769,  772,
#         774,  778,  782,  784,  791,  796,  798,  799,  801,  807,  813,
# ...
